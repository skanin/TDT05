# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
from lightgbm import LGBMClassifier

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

X = df_train.drop('target', axis=1)
y = df_train['target']

X_test = df_test

print(X.shape)
print(y.shape)
print(X_test.shape)
# Out:
# (50000, 30)
# (50000,)
# (50000, 30)

# %%
X.describe()
# Out:
#                  id            f4            f6            f8           f10  \
# count  50000.000000  48594.000000  48457.000000  48522.000000  48492.000000
# mean   24999.500000      6.988378      0.536847      4.112032      1.721665
# std    14433.901067      0.152945      0.656913      1.851792      3.427500
# min        0.000000      6.521800      0.000000      1.000000      0.000000
# 25%    12499.750000      6.870225      0.000000      3.000000      0.000000
# 50%    24999.500000      6.987500      0.000000      5.000000      0.000000
# 75%    37499.250000      7.102300      1.000000      6.000000      1.000000
# max    49999.000000      7.479400      2.000000      6.000000     11.000000
#
#                 f16           f17           f19           f21           f22  \
# count  48488.000000  48545.000000  48447.000000  48510.000000  48497.000000
# mean       6.362399      0.409113      4.120689      1.947784      0.628328
# std        3.455422      0.185697      2.034561      0.852700      0.483257
# min        1.000000      0.100000      1.000000      1.000000      0.000000
# 25%        3.000000      0.200000      2.000000      1.000000      0.000000
# 50%        6.000000      0.500000      5.000000      2.000000      1.000000
# 75%        8.000000      0.600000      6.000000      3.000000      1.000000
# max       12.000000      0.600000      7.000000      3.000000      1.000000
#
#                 f25           f28
# count  48501.000000  48535.000000
# mean      62.147378      0.537406
# std       33.086578      0.498604
# min        1.000000      0.000000
# 25%       32.000000      0.000000
# 50%       65.000000      1.000000
# 75%       94.000000      1.000000
# max      104.000000      1.000000

# %%
X.head()
# Out:
#    id f0   f1         f2         f3      f4 f5   f6 f7   f8  f9   f10 f11 f12  \
# 0   0  I   AU  134e98eb8  be42001f3  6.8928  B  0.0  R  4.0  PS   1.0  PS   a
# 1   1  N  NaN  232792002  3aad93cab  6.8098  A  1.0  G  6.0  DT  10.0  DT   f
# 2   2  P   JP  64e2a3589  90116a97d  6.7761  A  0.0  R  5.0  vq   0.0  vq   c
# 3   3  K   IT  960cdb2ef  dc4ee566b  6.9302  A  0.0  R  5.0  Bx   1.0  Bx   a
# 4   4  H   AU  8377590c9  f09cc205f  7.0238  A  1.0  G  5.0  kB   0.0  kB   d
#
#          f13 f14 f15   f16  f17        f18  f19        f20  f21  f22 f23 f24  \
# 0  0f94eb834   T   I   9.0  0.4  1d2ee04de  3.0  be0264098  3.0  0.0   B   N
# 1  5859a8a06   T   N  12.0  0.5  e06abf51f  1.0  71fb03996  3.0  1.0   F   N
# 2  7d7c02c57   T   P   5.0  0.2  5d1ac7760  2.0  bf987f83f  3.0  0.0   C   S
# 3  165e81a00   F   K   2.0  0.4  b0ab8b134  3.0  d40fcead7  2.0  0.0   D   N
# 4  35309e01b   T   H   8.0  0.6  0764632bc  6.0        NaN  2.0  1.0   A   S
#
#     f25        f26 f27  f28
# 0  51.0  1d2ee04de   m  1.0
# 1  10.0  e06abf51f   k  1.0
# 2  16.0  5d1ac7760   c  0.0
# 3  63.0  b0ab8b134   i  1.0
# 4  26.0  0764632bc   h  1.0

# %%
for elem in X:
    print(f'Column \'{elem}\': \n{X[elem].unique()}')
    print()
# Out:
# Column 'id':
# [    0     1     2 ... 49997 49998 49999]
#
# Column 'f0':
# ['I' 'N' 'P' 'K' 'H' 'A' 'Q' 'U' 'X' 'R' 'F' 'T' 'O' 'B' 'Y' 'M' 'W' 'Z'
#  'E' 'C' 'D' 'S' nan 'L' 'V' 'J' 'G']
#
# Column 'f1':
# ['AU' nan 'JP' 'IT' 'CN' 'DE']
#
# Column 'f2':
# ['134e98eb8' '232792002' '64e2a3589' ... 'f0732a795' '797b04033'
#  '695f3fe25']
#
# Column 'f3':
# ['be42001f3' '3aad93cab' '90116a97d' ... '7331b57f0' 'ccf3cdaeb'
#  'd1d7d8352']
#
# Column 'f4':
# [6.8928 6.8098 6.7761 ... 7.3393 7.4435 7.2826]
#
# Column 'f5':
# ['B' 'A' nan]
#
# Column 'f6':
# [ 0.  1.  2. nan]
#
# Column 'f7':
# ['R' 'G' 'B' nan]
#
# Column 'f8':
# [ 4.  6.  5. nan  1.  2.  3.]
#
# Column 'f9':
# ['PS' 'DT' 'vq' 'Bx' 'kB' 'mX' 'Mq' 'oJ' 'sc' 'Nh' 'gj' 'cy' 'Dj' 'Sz'
#  'rl' 'rg' 'rM' 'Rv' 'WW' 'vx' 'AU' 'BL' 'ok' 'aA' 'Tz' 'Oe' 'uQ' 'HK'
#  'pT' 'XM' 'yE' 'Lo' 'Fl' 'ly' 'JQ' 'RV' 'IS' 'MV' 'NS' 'Ji' 'tn' 'hT'
#  'qN' 'fe' 'dp' 'Ib' 'FH' 'zf' 'iS' 'YJ' 'eA' 'xG' 'WC' 'wa' 'sF' 'IA'
#  'lA' 'Sk' 'TZ' 'gc' 'Mg' 'AG' 'UV' 'iv' 'MF' 'uW' 'al' 'EC' 'zc' 'oI'
#  'qP' 'dh' 'Iq' 'Rj' nan 'AI' 'mi' 'rA' 'mo' 'hG' 'uP' 'GZ' 'DI' 'RD' 'RT'
#  'LS' 'nj' 'oh' 'oU' 'Pk' 'th' 'mD' 'gt' 'LY' 'aE' 'XC' 'eN' 'US' 'mP'
#  'nS' 'Yi' 'ht' 'jp' 'Hk' 'kT' 'Ay' 'SS' 'zp' 'OM' 'lS' 'Ey' 'Ty' 'PG'
#  'fO' 'QV' 'Rz' 'cR' 'CN' 'fV' 'TH' 'TL' 'DR' 'Pw' 'gL' 'Tg' 'ja' 'us'
#  'pZ' 'DN' 'XR' 'pE' 'OZ' 'Ox' 'AW' 'be' 'gK' 'hx' 'cY' 'Re' 'CU' 'pB'
#  'yK' 'TP' 'XU' 'HF' 'MU' 'xB' 'RB' 'jf' 'lR' 'kv' 'cg' 'ep' 'JT' 'sf'
#  'Wr' 'sY' 'NT' 'ne' 'In' 'wU' 'nn' 'MX' 'Kq' 'xF' 'wJ' 'vQ' 'Yr' 'pl'
#  'uZ' 'Io' 'vw' 'kP' 'ze' 'Cn' 'BX' 'uI' 'Ro' 'XI' 'tT' 'Dn' 'fF' 'Yb'
#  'SL' 'Qm' 'FB' 'HO' 'ur' 'Zv' 'nf' 'gV']
#
# Column 'f10':
# [ 1. 10.  0. nan 11.]
#
# Column 'f11':
# ['PS' 'DT' 'vq' 'Bx' 'kB' 'mX' 'Mq' 'oJ' 'sc' 'Nh' 'gj' 'cy' 'Dj' 'Sz'
#  'rl' 'rg' 'rM' 'Rv' 'WW' 'vx' 'AU' 'BL' 'ok' 'aA' 'Tz' 'Oe' 'uQ' 'HK'
#  'pT' 'XM' 'yE' 'Lo' 'Fl' 'ly' 'JQ' 'RV' 'IS' 'MV' 'NS' 'Ji' 'tn' 'hT'
#  'qN' 'fe' 'dp' 'Ib' 'FH' 'zf' 'iS' 'YJ' 'eA' 'xG' 'WC' 'wa' 'sF' 'IA'
#  'lA' 'Sk' 'TZ' 'gc' 'Mg' 'AG' 'UV' 'iv' 'MF' 'uW' 'al' 'EC' 'zc' 'oI'
#  'qP' 'dh' 'Iq' 'Rj' nan 'AI' 'mi' 'rA' 'mo' 'hG' 'uP' 'GZ' 'DI' 'RD' 'RT'
#  'LS' 'nj' 'oh' 'oU' 'Pk' 'th' 'mD' 'gt' 'LY' 'aE' 'XC' 'eN' 'US' 'mP'
#  'nS' 'Yi' 'ht' 'jp' 'Hk' 'kT' 'Ay' 'SS' 'zp' 'OM' 'lS' 'Ey' 'Ty' 'PG'
#  'fO' 'QV' 'Rz' 'cR' 'CN' 'fV' 'TH' 'TL' 'DR' 'Pw' 'gL' 'Tg' 'ja' 'us'
#  'pZ' 'DN' 'XR' 'pE' 'OZ' 'Ox' 'AW' 'be' 'gK' 'hx' 'cY' 'Re' 'CU' 'pB'
#  'yK' 'TP' 'XU' 'HF' 'MU' 'xB' 'RB' 'jf' 'lR' 'kv' 'cg' 'ep' 'JT' 'sf'
#  'Wr' 'sY' 'NT' 'ne' 'In' 'wU' 'nn' 'MX' 'Kq' 'xF' 'wJ' 'vQ' 'Yr' 'pl'
#  'uZ' 'Io' 'vw' 'kP' 'ze' 'Cn' 'BX' 'uI' 'Ro' 'XI' 'tT' 'Dn' 'fF' 'Yb'
#  'SL' 'Qm' 'FB' 'HO' 'ur' 'Zv' 'nf' 'gV']
#
# Column 'f12':
# ['a' 'f' 'c' 'd' nan 'e' 'b']
#
# Column 'f13':
# ['0f94eb834' '5859a8a06' '7d7c02c57' '165e81a00' '35309e01b' '5a7ade619'
#  'd48e8b7af' '74a092964' '9789d425f' 'f41dce3cc' '7861df0a8' 'bd9643a20'
#  'd9148f8e7' '745b909d1' '9c63b4d79' '587840371' 'fbbafaadc' '484c96b82'
#  nan '15f03b1f4' '1a59581be' '53efabb84' '32412c81c' '43a73e5ef'
#  'd8729dd2d' '5e348d538' '28869f8aa' 'af22df36a' '7c77c52f3' '75a957c6d'
#  'd1c6bb70d' '9dd6a02eb' '9f6ed3f30' '28c042258' 'c2036219b' '3d70f650d'
#  '8aeac2495' '6d3db6c57' 'e40c451d4' 'fbea9bb4a' '7d7394cbd' '1d88b0a79'
#  'b10ef207b' '154aacc1c' 'dcccc6c19' '0256c7a4b' '679b63eff' '0e5249dbe'
#  'cccbca824' 'e6061cbe7' '9417fa5d7' '220190c9e' '4164322bd' '153864851'
#  'da7e5f6fa' '60c7c84ee' 'cf30695f0' '6f853fd13' 'ad5be5be4' 'd6c8281a8'
#  'b42763706' '23dc2e63d' '590d9c11d' 'bccfd92a2' 'b279e09c3' 'c1a4acfaf'
#  '7e3a861d6' '8ce034bb6' 'd0ab86574' 'a1d71618d' 'fe070240a' '529b40fe8'
#  'a408ea8d6' '007bff22a' '1653ceb33' '25c087d05' '67d372885' 'b72c0bbc2'
#  'b8e63cace' '690411ac0' '29964d969' '6ab87efb1' 'e4a142d80' '63dde2492'
#  '4d31e3bf2' 'd8bad19d0' '634c43a77' '53419bedc' '32b33a4b4' 'ca9ad1d4b'
#  'a8009baf5' '10fd52d10' '46a005ddf' '210039295' 'fa49d4e04' '964a66013'
#  '5bdcf7324' '060a21580' 'f81a5366b' '22e0a764d' '574575c14' 'a625ea144'
#  '5a3040de6' 'ef752c107' '94a6512e2' 'f7b3f1d13' 'e0c7234cf' '158183c63'
#  '8109ba950' '3776bb1ae' 'a5eef5d8b' '1ce5cf721' 'e6873698e' '45121db5e'
#  '9cc561d1b' 'd5a47d599' 'cb0d7da76' 'e9fde8fa8' '798ccea46' '83fb0260e'
#  'ff3ba3bbc' 'd8e02864a' '1e722bf45' '2694748e3' '1fe15a999' 'ee474d72d'
#  '9416a52f9' 'cf233e69e' '777ce63ea' '4f727aeee' 'de6d6e3d8' '68f9b1267'
#  'f51683d93' '43e0ac7a1' '1df855856' '91b32f31b' '729cafb68' '0f269cbc8'
#  'ee0a32458' '44f8a6061' 'bdaa56dd1' '3fdf92cf7' '95414620e' 'd7e75499d'
#  '8e38a5c1b' '8dc88fa15' '7f06ae9e8' 'b4815ac52' '94c5fd40c' '862d2fbff'
#  'd06a44f23' '31db9b004' '750cb6661' 'dd674992f' 'e11794ad3' '2218d9dfe'
#  '77d41330d' '5f254ada1' '4abb8589e' '5c1c7fa53' '32ff72b97' '6eb21874b'
#  '573c92006' 'dda9ca69e' '4a5423b60' 'ee3c7aa8f' '2b34f5aca' '1c4931f19'
#  '9fa5832d8' '88eef0278' '9863487ba' '4918ca307' '3210cd7c1' 'f8510b161'
#  'cc5495ab3' '7a66737e5' '0279391c5' 'f635e7f7f' '52ead350c' '90e9e961e'
#  '82cc2cb4f' 'c9bbbb717' '704871e3b' '8d31d1ab3' '7ff3ee36e' '7c89e4b36'
#  '0602256df' '48982830e' '1195f603e' '56dbcd7de' '2061350b9' '9fcf4fab4'
#  '2c58293c4' '8d13bd3e9' '475f992f0' 'f338368af' '21595d82e' '2db5a9486'
#  'b33edbeb2' '7e7ddd679' '8637fc534' '6ff91d4e8' 'abce980f5' '563651ed8'
#  'cadc0cc42' '3e8a577e3' '79c79ecbf' '99bb7aedf' '954bb9489' 'fca8ae0cf'
#  '7217196aa' 'ceab144aa' '1b6796452' 'a89e1c1dc' '607c26084' '3d0ea8194'
#  '1f2cd223e' 'afb0fafb0' '4348381e1' '8df93e6c9' '4584d6fcd' '6492aecc3'
#  '115d9fd8b']
#
# Column 'f14':
# ['T' 'F' nan]
#
# Column 'f15':
# ['I' 'N' 'P' 'K' 'H' 'A' 'Q' 'U' 'X' 'R' 'F' 'T' 'O' 'B' 'Y' 'M' 'W' 'Z'
#  'E' 'C' 'D' 'S' nan 'L' 'V' 'J' 'G']
#
# Column 'f16':
# [ 9. 12.  5.  2.  8.  1.  3.  6. 11. nan  7.  4. 10.]
#
# Column 'f17':
# [0.4 0.5 0.2 0.6 0.1 nan 0.3]
#
# Column 'f18':
# ['1d2ee04de' 'e06abf51f' '5d1ac7760' 'b0ab8b134' '0764632bc' '018382adf'
#  '6536122f4' '58a27d7e7' '833d88c6c' 'cf84cbe77' 'b2151e2cd' nan
#  '11409e362' '942593b74' '088aace2d' 'a42fb9969' 'f14f5e4a5' '857cbf8c7'
#  '41afb892d' '623908296' '0c208bfa0' '3ef3018d3' '68b2de491' 'ba9faf5b1'
#  '7e1c4cff1' '8781919c2' '81d67e1bb' '1bd74ace9' '216083343' '8da514edb'
#  '77706a5ee' '00a7f9a05' '67a8d4ebb' 'debb0f7ec' '2c649f60e' '934155e05'
#  '20b56638c' '443cdbd48' 'fdebf0648' '3afd3697d' 'ba16219f4' '16fa03dee'
#  '8bc849561' '74a864a6b' '7fcdbac1d' '362507ea5' '12370b989' '1c756c04a'
#  'e4340c326' '3d9d8f526' '0e4d3318a' 'bc9cc2a94' 'a306b1f4e' '768bc4738'
#  '237fdf58b' 'c79d2197d' '0eb5e9781' '93360bbc9' '0304a1b60' '2786e24d2'
#  '688888fbe' '3f63ecb96' '86ec768cd' 'b519f5dff' '2aeb8ae84' 'e61c53286'
#  '3599d0255' 'bb63fcef7' '4ae48e857' '8c9b654fe' '303f4e39a' 'ece4087ec'
#  '41901460a' 'f12d5e8c0' '5e17197af' 'a0730843f' '9b35d8994' '4b13d99ca'
#  '56d35c774' 'cb681246b' 'cd9feb5c6' '51e1131b4' '8d857a0a1' 'ffe61f9f6'
#  '057ab40ea' 'd40ca0718' '6e29d3f38' '21955ee26' 'c5f7d2efd' 'f74f0b894'
#  'd3d8f55e0' '22a1b223f' '85fb6971c' '69403e18c' 'fba315672' 'e5b00a0e0'
#  '429114096' 'a7059911d' '6bc753dd6' '8402256f6' 'fff8dea99' '01103c3e4'
#  'b97010abc' '5622ee17f' '199d01a7f' '31a3c86df' '4617418f2' '7ab87e58e'
#  'ead914edc' '0ffdb2c15' '230229e51' 'e44e2dea4' '3c415c2b7' 'e59dd3e27'
#  '8a528cb08' 'c3ad85934' 'd2ecbd100' '1bf2f7824' '4f0a50007' '1dddb8473'
#  '5d5b262b1' 'ab85a7b9c' '3600c6e91' 'f94d9babd' '69238b544' '9a9e7bf71'
#  '1cba571fa' '9fed600dc' '7f6fad56e' 'b4d7d7c94' '2c4f9614e' '7f31f4d2b'
#  '99cb99a50' '8157480dd' '63ab45432' '83bdea3a5' 'e3342b01a' 'b2d0012ea'
#  '8a382f14d' '3d449d3e8' '9294ac66b' '28547ea20' '482233c7f' '728490578'
#  '2b2108e9e' '1828818ab' '5ddc9a726' 'b4eb50264' '27560c3a3' 'c273b5ace'
#  '0da2378c8' '580231f65' '7684d9eb7' 'e60e65034' '9d4a94d03' 'dd4d69481'
#  '598080a91' '5627228e9' '51a4ac0be' 'b4678a59e' '2506ce93d' '6602f7bf5'
#  '114b1dbf3' 'd8c3cfd78' '82d196aa1' '81b479cc3' '964fd0850' '6b1d5295a'
#  'c9aaf28b7' '909943002' '91208fa55' 'adbdefba3' '97bb3e7fa' '42c7572b4'
#  '3efdc7987' '082e2b9ae' '40bdb3373' '25eb75323' 'ec4b54637' '1ba4e8ff1'
#  '6b56b4325' '3a33ef960' '190522cfb' '432ee0053' '8c30b9b0b' '7b21ee165'
#  '6c7aa4dc4' '54f62d537' '7bf938847' '4b41ba86c' '3f2e87b23' 'f313d1e52'
#  '567934479' '8fc780921' '90a2cba07' 'cb47f665d' '4be936718' 'afac5238e'
#  '9d52e9089' '9289b1aab' '75d0e3ef8' 'd7f06353a' '3065f26f4' '42f607baa'
#  '1eb783b97' 'ac365406b' '5de0b3fa7' '7b4b2eabf' '83c994142' '8dbc78da5'
#  '84b44fe42' '16e07c05c' 'e371063e2' '545ad7c80' '94d34d287' 'a8cfb0795'
#  'b39008216' '3d2d50707' '2fa636740' '49ae7bdc0' '8046bea1a' 'deec583dd'
#  'e9c57c4aa']
#
# Column 'f19':
# [ 3.  1.  2.  6.  5.  7.  4. nan]
#
# Column 'f20':
# ['be0264098' '71fb03996' 'bf987f83f' ... '3c7bba9c4' 'd61dbecb0'
#  '00616c066']
#
# Column 'f21':
# [ 3.  2.  1. nan]
#
# Column 'f22':
# [ 0.  1. nan]
#
# Column 'f23':
# ['B' 'F' 'C' 'D' 'A' 'E' nan]
#
# Column 'f24':
# ['N' 'S' nan]
#
# Column 'f25':
# [ 51.  10.  16.  63.  26. 103.  70.  65.  52.   5.  37.  84.  34. 104.
#   41.  44.  69.  64. 100.  73.  39.  78.  28.  12.  97.  40.  68.  85.
#  102.  22.  nan  42.  79.  32.  89.  92.   3.  49.  80.  90.  91.  30.
#   82.  74.  83.  87.  47.  25.  13.  31.  99.  18.  27.  95.  94.  11.
#   19.  62.  67.  46.  88.  45.  48.  66.  50.  38.  56.  96.  20. 101.
#   55.   1.  71.  60.  81.  24.  43.  36.  17.   4.  61.   7.  98.  86.
#   75.  93.   6.  35.  23.   9.  53.  57.  33.  76.   8.  59.  14.  21.
#   72.   2.  29.  15.  58.  54.  77.]
#
# Column 'f26':
# ['1d2ee04de' 'e06abf51f' '5d1ac7760' 'b0ab8b134' '0764632bc' '018382adf'
#  '6536122f4' '58a27d7e7' '833d88c6c' 'cf84cbe77' 'b2151e2cd' nan
#  '11409e362' '942593b74' '088aace2d' 'a42fb9969' 'f14f5e4a5' '857cbf8c7'
#  '41afb892d' '623908296' '0c208bfa0' '3ef3018d3' '68b2de491' 'ba9faf5b1'
#  '7e1c4cff1' '8781919c2' '81d67e1bb' '1bd74ace9' '216083343' '8da514edb'
#  '77706a5ee' '00a7f9a05' '67a8d4ebb' 'debb0f7ec' '2c649f60e' '9.34E+10'
#  '20b56638c' '443cdbd48' 'fdebf0648' '3afd3697d' 'ba16219f4' '16fa03dee'
#  '8bc849561' '74a864a6b' '7fcdbac1d' '362507ea5' '12370b989' '1c756c04a'
#  'e4340c326' '3d9d8f526' '0e4d3318a' 'bc9cc2a94' 'a306b1f4e' '768bc4738'
#  '237fdf58b' 'c79d2197d' '0eb5e9781' '93360bbc9' '0304a1b60' '2786e24d2'
#  '688888fbe' '3f63ecb96' '86ec768cd' 'b519f5dff' '2aeb8ae84' 'e61c53286'
#  '3599d0255' 'bb63fcef7' '4ae48e857' '8c9b654fe' '303f4e39a' 'ece4087ec'
#  '41901460a' 'f12d5e8c0' '5e17197af' 'a0730843f' '9b35d8994' '4b13d99ca'
#  '56d35c774' 'cb681246b' 'cd9feb5c6' '51e1131b4' '8d857a0a1' 'ffe61f9f6'
#  '057ab40ea' 'd40ca0718' '6e29d3f38' '21955ee26' 'c5f7d2efd' 'f74f0b894'
#  'd3d8f55e0' '22a1b223f' '85fb6971c' '69403e18c' 'fba315672' 'e5b00a0e0'
#  '429114096' 'a7059911d' '6bc753dd6' '8402256f6' 'fff8dea99' '01103c3e4'
#  'b97010abc' '5622ee17f' '199d01a7f' '31a3c86df' '4617418f2' '7ab87e58e'
#  'ead914edc' '0ffdb2c15' '2.30E+56' 'e44e2dea4' '3c415c2b7' 'e59dd3e27'
#  '8a528cb08' 'c3ad85934' 'd2ecbd100' '1bf2f7824' '4f0a50007' '1dddb8473'
#  '5d5b262b1' 'ab85a7b9c' '3600c6e91' 'f94d9babd' '69238b544' '9a9e7bf71'
#  '1cba571fa' '9fed600dc' '7f6fad56e' 'b4d7d7c94' '2c4f9614e' '7f31f4d2b'
#  '99cb99a50' '8157480dd' '63ab45432' '83bdea3a5' 'e3342b01a' 'b2d0012ea'
#  '8a382f14d' '3d449d3e8' '9294ac66b' '28547ea20' '482233c7f' '728490578'
#  '2b2108e9e' '1828818ab' '5ddc9a726' 'b4eb50264' '27560c3a3' 'c273b5ace'
#  '0da2378c8' '580231f65' '7684d9eb7' 'e60e65034' '9d4a94d03' 'dd4d69481'
#  '598080a91' '5.63E+15' '51a4ac0be' 'b4678a59e' '2506ce93d' '6602f7bf5'
#  '114b1dbf3' 'd8c3cfd78' '82d196aa1' '81b479cc3' '964fd0850' '6b1d5295a'
#  'c9aaf28b7' '909943002' '91208fa55' 'adbdefba3' '97bb3e7fa' '42c7572b4'
#  '3efdc7987' '082e2b9ae' '40bdb3373' '25eb75323' 'ec4b54637' '1ba4e8ff1'
#  '6b56b4325' '3a33ef960' '190522cfb' '432ee0053' '8c30b9b0b' '7b21ee165'
#  '6c7aa4dc4' '54f62d537' '7bf938847' '4b41ba86c' '3f2e87b23' 'f313d1e52'
#  '567934479' '8fc780921' '90a2cba07' 'cb47f665d' '4be936718' 'afac5238e'
#  '9d52e9089' '9289b1aab' '75d0e3ef8' 'd7f06353a' '3065f26f4' '42f607baa'
#  '1eb783b97' 'ac365406b' '5de0b3fa7' '7b4b2eabf' '83c994142' '8dbc78da5'
#  '84b44fe42' '16e07c05c' 'e371063e2' '545ad7c80' '94d34d287' 'a8cfb0795'
#  'b39008216' '3d2d50707' '2fa636740' '49ae7bdc0' '8046bea1a' 'deec583dd'
#  'e9c57c4aa']
#
# Column 'f27':
# ['m' 'k' 'c' 'i' 'h' 'b' 'n' 'o' 'a' 'e' 'd' nan 'g' 'f' 'l' 'j']
#
# Column 'f28':
# [ 1.  0. nan]

# %% [markdown]
# After inspecting each column, it looks as though column f0 and f15 are the same and f9 and f11 are the same, which also seems to be the case (see below.)
#
# Columns f28 and f22 contains only binary values.
#
# Columns f2, f3, f13, f18, f20 and f26 contains hexadecimal values
#
# Column f28 contains only binary values.
#
# Column f27 contains the letters from a-m.
#
# Column f26 contains only hexadecimal values
#
# Column f25 contains the values 1-104
#
# Column f24 contains only "N" and "S" (North, south?)
#
# Column f23 contains only A-F (grades?)
#
# Column f22 contains only binary values.
#
# Column f21 contains the values 1-3
#
# Column f20 contains only hexadecimal values
#
# Column f19 contains the values 1-7
#
# Column f18 contains only hexadecimal values
#
# Column f17 contains the values .1 - .6
#
# Column f16 contains the values 1-12
#
# Column f15 contains the alphabet
#
# Column f14 contains only T and F, which _could_ be True/False.
#
# Column f13 contains only hexadecimal values
#
# Column f12 contains the letters a-f (grades?) NOT THE SAME AS F23
#
# Column f11 contains strings with two letters
#
# Column f10 contains only the values 0, 1, 10 and 11
#
# Column f9 contains strings with two letters
#
# Column f8 contains the values 1-6
#
# Column f7 contains only R, G, B (which might be Red, Green, Blue?)
#
# Column f6 contains only the values 0-2
#
# Column f5 contains only "A" and "B"
#
# Column f4 contains floats
#
# Column f3 contains only hexadecimal values
#
# Column f2 contains only hexadecimal values
#
# Column f1 contains only 'AU', 'CN', 'DE', 'IT', 'JP'
#
# Column f0 contains the alphabet

# %%
print('F0 == F15?', end=' ')
print(X['f0'].equals(X['f15']))

print('F9 == F11?', end=' ')
print(X['f9'].equals(X['f11']))

print('F9 == F11?', end=' ')
print(X['f12'].dropna().equals(X['f23'].dropna().apply(lambda x:x.lower())))
# Out:
# F0 == F15? True
# F9 == F11? True
# F9 == F11? False

# %%
np.sort(X['id'].dropna().unique())
# Out:
# 1207

# %%
hex_columns = ['f2', 'f3', 'f13', 'f18', 'f20', 'f26']
bool_columns = ['f28', 'f22', 'f14']
ordinal_columns = ['f6', 'f8', 'f16', 'f17', 'f19', 'f21', 'f25']
categorical_columns = ['f1', 'f5', 'f7', 'f9', 'f10', 'f11', 'f23', 'f24', 'f27']
numerical_columns = ['f4']

# %%
lgbm = LGBMClassifier(objective='multiclass', random_state=5)

lgbm.fit(X, y)

y_pred = lgbm.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6k/gbkhg10x5w53pgl5910p6m240000gn/T/ipykernel_22686/2541904902.py in <module>
#       1 lgbm = LGBMClassifier(objective='multiclass', random_state=5)
#       2
# ----> 3 lgbm.fit(X, y)
#       4
#       5 y_pred = lgbm.predict(X_test)
#
# /usr/local/lib/python3.9/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     888                     valid_sets[i] = (valid_x, self._le.transform(valid_y))
#     889
# --> 890         super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#     891                     eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     892                     eval_class_weight=eval_class_weight, eval_init_score=eval_init_score,
#
# /usr/local/lib/python3.9/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     681             init_model = init_model.booster_
#     682
# --> 683         self._Booster = train(params, train_set,
#     684                               self.n_estimators, valid_sets=valid_sets, valid_names=eval_names,
#     685                               early_stopping_rounds=early_stopping_rounds,
#
# /usr/local/lib/python3.9/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     226     # construct booster
#     227     try:
# --> 228         booster = Booster(params=params, train_set=train_set)
#     229         if is_valid_contain_train:
#     230             booster.set_train_data_name(train_data_name)
#
# /usr/local/lib/python3.9/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2227                 )
#    2228             # construct booster object
# -> 2229             train_set.construct()
#    2230             # copy the parameters from train_set
#    2231             params.update(train_set.get_params())
#
# /usr/local/lib/python3.9/site-packages/lightgbm/basic.py in construct(self)
#    1466             else:
#    1467                 # create train
# -> 1468                 self._lazy_init(self.data, label=self.label,
#    1469                                 weight=self.weight, group=self.group,
#    1470                                 init_score=self.init_score, predictor=self._predictor,
#
# /usr/local/lib/python3.9/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1207             self.pandas_categorical = reference.pandas_categorical
#    1208             categorical_feature = reference.categorical_feature
# -> 1209         data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#    1210                                                                                              feature_name,
#    1211                                                                                              categorical_feature,
#
# /usr/local/lib/python3.9/site-packages/lightgbm/basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     535         bad_indices = _get_bad_pandas_dtypes(data.dtypes)
#     536         if bad_indices:
# --> 537             raise ValueError("DataFrame.dtypes for data must be int, float or bool.\n"
#     538                              "Did not expect the data types in the following fields: "
#     539                              + ', '.join(data.columns[bad_indices]))
#
# ValueError: DataFrame.dtypes for data must be int, float or bool.
# Did not expect the data types in the following fields: f0, f1, f2, f3, f5, f7, f9, f11, f12, f13, f14, f15, f18, f20, f23, f24, f26, f27
